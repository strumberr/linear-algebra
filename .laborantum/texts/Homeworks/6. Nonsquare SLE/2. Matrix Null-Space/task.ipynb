# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../../../../code/')
sys.path.append('code')

# %%
# import numpy
# import json_tricks
# import os

# numpy.random.seed(42)

# debug_cases = []
# for index in range(20):
#     A_shape = numpy.random.randint(1, 10, size=[2])
    
#     # A_shape[1] = A_shape[0]
#     if A_shape[0] > A_shape[1]:
#         A_shape[[0, 1]] = A_shape[[1, 0]]

#     A = numpy.random.randint(-4, 4, size=A_shape).astype(float)

#     debug_cases.append({'A': A})

# os.makedirs('testcases', exist_ok=True)
# with open('testcases/debug_cases.json', 'w+') as fin:
#     fin.write(json_tricks.dumps(debug_cases))

# public_cases = []
# for index in range(100):
#     A_shape = numpy.random.randint(1, 10, size=[2])
    
#     # A_shape[1] = A_shape[0]
#     if A_shape[0] > A_shape[1]:
#         A_shape[[0, 1]] = A_shape[[1, 0]]

#     A = numpy.random.randint(-5, 5, size=A_shape).astype(float)

#     # print(A)

#     # print(numpy.linalg.det(A_low), numpy.linalg.det(A_up))
#     # print(numpy.linalg.det(A))

#     public_cases.append({'A': A})

# with open('testcases/public_cases.json', 'w+') as fin:
#     fin.write(json_tricks.dumps(public_cases))

# %%
from find_kernel import find_kernel
import numpy as np

# %%
import sys
import os
from pathlib import Path
import json_tricks

path = Path('.').resolve()

index = str(path).find('.laborantum')

if index > 0:
    path = str(path)[:index]

os.chdir(path)

path = Path('.laborantum/texts/Homeworks/6. Nonsquare SLE/2. Matrix Null-Space')

debug_cases = json_tricks.load(
    str(path / 'testcases' / 'debug_cases.json'))
public_cases = json_tricks.load(
    str(path / 'testcases' / 'public_cases.json'))


# print(public_cases)

# %%
import time

start = time.time()

print("Debug")
debug_result = [find_kernel(**x) for x in debug_cases]

print("Public")
answer = [find_kernel(**x) for x in public_cases]

print(time.time() - start, '<- Elapsed time')
# Out:
# Debug
# Public
# 0.017670154571533203 <- Elapsed time

# %%
print("Checking misfits |Ax - b|:")
print("Misfit should be < 1.0e-8")
print()
print('=' * 5 + ' DEBUG CASES ' + '='*5)
for index in range(len(debug_result)):
    case = debug_cases[index]
    NS = debug_result[index]

    A = case['A']
    
    print(
        'Case #' + str(index),
        np.abs(A @ NS).sum())
    

print()
print('=' * 5 + ' TEST CASES ' + '=' * 5)
for index in range(len(answer)):
    case = public_cases[index]
    NS = answer[index]

    A = case['A']
    # b = case['b']

    # print(A)
    # print(numpy.linalg.inv(A))
    # print(numpy.linalg.det(A))

    # print(A.shape, A_inv.shape)
    print(
        'Case #' + str(index),
        np.abs(A @ NS).sum())
print('=' * 5 + ' END ' + '=' * 5)
# Out:
# Checking misfits |Ax - b|:
# Misfit should be < 1.0e-8
#
# ===== DEBUG CASES =====
# Case #0 3.1086244689504383e-15
# Case #1 0.0
# Case #2 0.0
# Case #3 1.3322676295501878e-15
# Case #4 1.033895191682177e-15
# Case #5 3.419486915845482e-14
# Case #6 1.3322676295501878e-15
# Case #7 1.1324274851176597e-14
# Case #8 4.440892098500626e-15
# Case #9 0.0
# Case #10 4.440892098500626e-16
# Case #11 0.0
# Case #12 0.0
# Case #13 3.552713678800501e-15
# Case #14 4.440892098500626e-16
# Case #15 4.884981308350689e-15
# Case #16 8.881784197001252e-16
# Case #17 0.0
# Case #18 0.0
# Case #19 0.0
#
# ===== TEST CASES =====
# Case #0 5.745404152435185e-15
# Case #1 0.0
# Case #2 0.0
# Case #3 0.0
# Case #4 3.774758283725532e-15
# Case #5 0.0
# Case #6 8.881784197001252e-16
# Case #7 0.0
# Case #8 6.217248937900877e-15
# Case #9 5.10702591327572e-15
# Case #10 5.10702591327572e-15
# Case #11 0.0
# Case #12 0.0
# Case #13 0.0
# Case #14 6.039613253960852e-14
# Case #15 6.163472510145596e-15
# Case #16 0.0
# Case #17 0.0
# Case #18 1.1546319456101628e-14
# Case #19 2.55351295663786e-15
# Case #20 0.0
# Case #21 2.6645352591003757e-15
# Case #22 4.773959005888173e-15
# Case #23 3.858025010572419e-15
# Case #24 1.0196288258157438e-12
# Case #25 0.0
# Case #26 0.0
# Case #27 0.0
# Case #28 1.3322676295501878e-15
# Case #29 0.0
# Case #30 6.716849298982197e-15
# Case #31 2.2537527399890678e-14
# Case #32 0.0
# Case #33 0.0
# Case #34 4.218847493575595e-15
# Case #35 7.105427357601002e-15
# Case #36 0.0
# Case #37 0.0
# Case #38 5.329070518200751e-15
# Case #39 2.220446049250313e-16
# Case #40 1.3322676295501878e-15
# Case #41 0.0
# Case #42 2.6645352591003757e-15
# Case #43 5.10702591327572e-15
# Case #44 0.0
# Case #45 5.773159728050814e-15
# Case #46 8.881784197001252e-14
# Case #47 1.5987211554602254e-14
# Case #48 0.0
# Case #49 0.0
# Case #50 0.0
# Case #51 0.0
# Case #52 5.162537064506978e-15
# Case #53 0.0
# Case #54 0.0
# Case #55 0.0
# Case #56 0.0
# Case #57 0.0
# Case #58 0.0
# Case #59 0.0
# Case #60 0.0
# Case #61 1.021405182655144e-14
# Case #62 9.992007221626409e-15
# Case #63 4.884981308350689e-15
# Case #64 4.440892098500626e-16
# Case #65 2.5757174171303632e-14
# Case #66 1.9984014443252818e-15
# Case #67 0.0
# Case #68 0.0
# Case #69 0.0
# Case #70 5.995204332975845e-15
# Case #71 2.6645352591003757e-15
# Case #72 1.1102230246251565e-15
# Case #73 4.440892098500626e-16
# Case #74 3.1086244689504383e-15
# Case #75 0.0
# Case #76 3.3306690738754696e-15
# Case #77 0.0
# Case #78 3.552713678800501e-15
# Case #79 0.0
# Case #80 0.0
# Case #81 9.547918011776346e-15
# Case #82 0.0
# Case #83 0.0
# Case #84 0.0
# Case #85 0.0
# Case #86 2.1094237467877974e-15
# Case #87 0.0
# Case #88 3.774758283725532e-15
# Case #89 2.2026824808563106e-13
# Case #90 0.0
# Case #91 0.0
# Case #92 3.197442310920451e-14
# Case #93 9.325873406851315e-15
# Case #94 0.0
# Case #95 0.0
# Case #96 1.1546319456101628e-14
# Case #97 2.6645352591003757e-15
# Case #98 0.0
# Case #99 0.0
# ===== END =====
